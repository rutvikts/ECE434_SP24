# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from scipy.fft import fft, fftfreq

# # Import .wav file
# sample_rate, samples = wavfile.read('Q6/ECE434_HW2_MyNameIs.wav')

# # Take FFT
# fft_data = fft(samples)

# # Number of sample points
# N = len(samples)

# # sample spacing
# T = 1.0 / sample_rate

# # Create x-axis space
# x = np.linspace(0.0, N*T, N, endpoint=False)
# xf = fftfreq(N, T)[:N//2]

# # Plot
# plt.plot(xf[0:N//2], 2/N*np.abs(fft_data[0:N//2]), label='Amplitude spectrum')
# plt.title("Magnitude of FFT of 'My Name is Rutvik'")
# plt.ylabel("Magnitude")
# plt.xlabel("Frequency (Hz)")
# plt.legend()
# plt.grid()
# plt.show()

# D_1 = np.array([2,9,10,7,2,6,8,16,14])
# D_2 = np.array([4,12,14,8,5,7,11,16,10])

# print("Covariance of arrays: ", np.cov(D_1, D_2))


# Define the parameters
f1 = 1  # Frequency of the signal
Ts = 0.1  # Sampling period
N = 512  # Number of samples for DFT

# Generate the time vector
n = np.arange(N)

# Generate the signal x[n]
x_n = np.cos(2 * np.pi * f1 * n * Ts) + np.sin(2 * np.pi * f1 * n * Ts) + np.sin(4 * np.pi * f1 * n * Ts)

# Compute the Discrete Fourier Transform (DFT)
X_k = np.fft.fft(x_n, N)

# Frequency vector
freq = np.fft.fftfreq(N, d=Ts)

# Plot the magnitude response (Bode plot)
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.plot(freq[:N//2], np.abs(X_k)[:N//2])
plt.title('Magnitude Response')
plt.xlabel('Frequency (Hz)')
plt.ylabel('|X[k]|')

# Plot the phase response
plt.subplot(2, 1, 2)
plt.plot(freq[:N//2], np.angle(X_k, deg=True)[:N//2])
plt.title('Phase Response')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Phase (degrees)')
plt.tight_layout()
plt.show()
